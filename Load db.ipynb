# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Open zillow home values, school data and merged files
homevalues_cook_2019_df=pd.read_csv("Resources\Data\clean_homevalue_2019.csv").drop(["Unnamed: 0"], axis=1)
schools_data_df= pd.read_csv("Resources\Data\cleaned_schools_data.csv").drop(["Unnamed: 0"], axis=1)
merged_df= pd.read_csv("Resources\Data\Schools_data_homevalue_merged.csv").drop(["Unnamed: 0"], axis=1)

# %%
merged_df.head()
# Out:
#           RCDTS                        School_Name  School_Type County  \
# 0  5.016200e+13           Evanston Twp High School  HIGH SCHOOL   Cook
# 1  5.016200e+13    New Trier Township H S Winnetka  HIGH SCHOOL   Cook
# 2  5.016200e+13  New Trier Township H S Northfield  HIGH SCHOOL   Cook
# 3  5.016210e+13             Maine East High School  HIGH SCHOOL   Cook
# 4  5.016210e+13            Maine South High School  HIGH SCHOOL   Cook
#
#    #_Student_Enrollment  Perc_Student_Enrollment_Low_Income  \
# 0                  3514                                36.5
# 1                  2963                                 4.2
# 2                  1015                                 2.6
# 3                  1852                                41.6
# 4                  2391                                 6.4
#
#    Student_Attendance_Rate  $_Site_level_Per_Pupil_Expenditures_Subtotal  \
# 0                     91.5                                      20271.00
# 1                     94.9                                      22428.80
# 2                     96.2                                      22281.03
# 3                     91.9                                      13382.03
# 4                     93.8                                      12801.70
#
#    $_District_Centralized_Per_Pupil_Expenditure_Subtotal  \
# 0                                            1949.00
# 1                                            3076.44
# 2                                            3076.44
# 3                                            5994.55
# 4                                            5919.13
#
#    $_Total_Per_Pupil_Expenditures_Subtotal  SAT_Reading_Average  \
# 0                                 22220.00                540.1
# 1                                 25505.24                611.9
# 2                                 25357.47                  NaN
# 3                                 19376.58                491.2
# 4                                 18720.83                559.6
#
#    SAT_Math_Average           Address        City County_Name Rec_Type    Zip  \
# 0             540.7    1600 Dodge Ave    Evanston        Cook      Sch  60201
# 1             627.6  385 Winnetka Ave    Winnetka        Cook      Sch  60093
# 2               NaN         7 Happ Rd  Northfield        Cook      Sch  60093
# 3             497.3  2601 Dempster St  Park Ridge        Cook      Sch  60068
# 4             577.8     1111 S Dee Rd  Park Ridge        Cook      Sch  60068
#
#          Lat        Lng  Avg_Home_Value
# 0  42.047544 -87.699769       511257.00
# 1  42.094380 -87.719263      1111715.17
# 2  42.094887 -87.766762      1111715.17
# 3  42.037380 -87.857584       421220.75
# 4  42.001374 -87.852285       421220.75

# %%
# Rename Columns with % to avoid running into errors with SQL
merged_df.rename(columns={"%_Student_Enrollment_Low_Income": "Perc_Student_Enrollment_Low_Income"}, inplace=True)
merged_df.head()
# Out:
#           RCDTS                        School_Name  School_Type County  \
# 0  5.016200e+13           Evanston Twp High School  HIGH SCHOOL   Cook
# 1  5.016200e+13    New Trier Township H S Winnetka  HIGH SCHOOL   Cook
# 2  5.016200e+13  New Trier Township H S Northfield  HIGH SCHOOL   Cook
# 3  5.016210e+13             Maine East High School  HIGH SCHOOL   Cook
# 4  5.016210e+13            Maine South High School  HIGH SCHOOL   Cook
#
#    #_Student_Enrollment  Perc_Student_Enrollment_Low_Income  \
# 0                  3514                                36.5
# 1                  2963                                 4.2
# 2                  1015                                 2.6
# 3                  1852                                41.6
# 4                  2391                                 6.4
#
#    Student_Attendance_Rate  $_Site_level_Per_Pupil_Expenditures_Subtotal  \
# 0                     91.5                                      20271.00
# 1                     94.9                                      22428.80
# 2                     96.2                                      22281.03
# 3                     91.9                                      13382.03
# 4                     93.8                                      12801.70
#
#    $_District_Centralized_Per_Pupil_Expenditure_Subtotal  \
# 0                                            1949.00
# 1                                            3076.44
# 2                                            3076.44
# 3                                            5994.55
# 4                                            5919.13
#
#    $_Total_Per_Pupil_Expenditures_Subtotal  SAT_Reading_Average  \
# 0                                 22220.00                540.1
# 1                                 25505.24                611.9
# 2                                 25357.47                  NaN
# 3                                 19376.58                491.2
# 4                                 18720.83                559.6
#
#    SAT_Math_Average           Address        City County_Name Rec_Type    Zip  \
# 0             540.7    1600 Dodge Ave    Evanston        Cook      Sch  60201
# 1             627.6  385 Winnetka Ave    Winnetka        Cook      Sch  60093
# 2               NaN         7 Happ Rd  Northfield        Cook      Sch  60093
# 3             497.3  2601 Dempster St  Park Ridge        Cook      Sch  60068
# 4             577.8     1111 S Dee Rd  Park Ridge        Cook      Sch  60068
#
#          Lat        Lng  Avg_Home_Value
# 0  42.047544 -87.699769       511257.00
# 1  42.094380 -87.719263      1111715.17
# 2  42.094887 -87.766762      1111715.17
# 3  42.037380 -87.857584       421220.75
# 4  42.001374 -87.852285       421220.75

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/Project_2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['schools', 'homevalues', 'schools_homevalues']

# %% [markdown]
# ### Load DataFrames into database

# %%
homevalues_cook_2019_df.to_sql(name='homevalues', con=engine, if_exists='append', index=False)

# %%
schools_data_df.to_sql(name='schools', con=engine, if_exists='append', index=False)

# %%
merged_df.to_sql(name='schools_homevalues', con=engine, if_exists='append', index=False)
